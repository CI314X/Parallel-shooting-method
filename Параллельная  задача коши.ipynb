# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rank = 1
ksi = 0.730356; eta = 1.301966
N = 100
size = 4
eps = 1e-3;
h = (1.0 / size) / N;
x0 = 1.0/size*rank;
y = np.zeros(N+1)
v = np.zeros(N+1)
x_arr = np.zeros_like(y)
y[0] = ksi
v[0] = eta
for r in range(1):
    x = x0
    for i in range(N):
        x_arr[i] = x
        k11 = v[i]
        k21 = func(x, y[i], v[i])
        k22 = func(x + h / 2, y[i] + h / 2 * k21, v[i] + h / 2 * k11)
        y[i + 1] = y[i] + h * k11
        v[i + 1] = v[i] + h * k22
        x += h
x_arr[N] = x       
print(y[N])
print(v[N])
print(x0)
# Out:
# 1.1394002586809793
# 2.03559457098391
# 0.25

# %%
Рунге кутты 4 порядка

# %%
rank = 0
#ksi = 0.730356; eta = 1.301966
ksi = 0.73003; eta = 1.301
ksi = 0; eta = 1
N = 100
size = 4
eps = 1e-3;
h = (1.0 / size) / N;
x0 = 1.0/size*rank;
y = np.zeros(N+1)
v = np.zeros(N+1)
x_arr = np.zeros_like(y)
y[0] = ksi
v[0] = eta
for r in range(1):
    x = x0
    for i in range(N):
        x_arr[i] = x
        k1 = h * func(x,y[i],v[i])
        q1 = h * v[i]
        k2 = h * func(x + h/2.0,y[i] + q1/2.0,v[i] + k1/2.0)
        q2 = h * (v[i] + k1/2.0)
        k3 = h * func(x + h/2.0,y[i] + q2/2.0,v[i] + k2/2.0)
        q3 = h * (v[i] + k2/2.0)
        k4 = h * func(x + h,y[i] + q3,v[i] + k3)
        q4 = h * (v[i] + k3)
        #(k1+2*k2+2*k3+k4)/6.0
        #(q1+2*q2+2*q3+q4)/6.0
        #y[i+1] = y[i] + (k1+2*k2+2*k3+k4)/6.0
        #v[i+1] = v[i] + (q1+2*q2+2*q3+q4)/6.0
        y[i+1] = y[i] + (q1+2*q2+2*q3+q4)/6.0
        v[i+1] = v[i] + (k1+2*k2+2*k3+k4)/6.0
        x += h
x_arr[N] = x       
print(y[N])
print(v[N])
print(x0, x)
plt.plot(x_arr, y)
# Out:
# 0.5954062545491628
# 4.432468784340558
# 0.0 0.25000000000000017

# %%
ksi = 0; eta = 1
N = 100
size = 4
h = (1.0 / size) / N;
x0 = 0
y = np.zeros(N*size)
v = np.zeros_like(y)
x_arr = np.zeros_like(y)
y[0] = ksi
v[0] = eta
for r in range(1):
    x = x0
    for i in range(N*size-1):
        x_arr[i] = x
        k1 = h * func(x,y[i],v[i])
        q1 = h * v[i]
        k2 = h * func(x + h/2.0,y[i] + q1/2.0,v[i] + k1/2.0)
        q2 = h * (v[i] + k1/2.0)
        k3 = h * func(x + h/2.0,y[i] + q2/2.0,v[i] + k2/2.0)
        q3 = h * (v[i] + k2/2.0)
        k4 = h * func(x + h,y[i] + q3,v[i] + k3)
        q4 = h * (v[i] + k3)
        #(k1+2*k2+2*k3+k4)/6.0
        #(q1+2*q2+2*q3+q4)/6.0
        #y[i+1] = y[i] + (k1+2*k2+2*k3+k4)/6.0
        #v[i+1] = v[i] + (q1+2*q2+2*q3+q4)/6.0
        y[i+1] = y[i] + (q1+2*q2+2*q3+q4)/6.0
        v[i+1] = v[i] + (k1+2*k2+2*k3+k4)/6.0
        x += h
x_arr[-1] = x       
print(y[N])
print(v[N])
print(x0, x)
plt.plot(x_arr, y)
# Out:
# 0.5954062545491628
# 4.432468784340558
# 0 0.9974999999999897

# %%
c1 = 1/(np.exp(3)-np.exp(1))
def ans(x):
    return -c1*np.exp(x) + c1*np.exp(3*x)
N = 11
size = 4
x = np.linspace(0,1,N*size)
y = ans(x)
plt.plot(x,y)

# %%
plt.plot(x,y_ret)

# %%
li=[0, 1,
0.002, 0.998978,
0.004, 0.997956,
0.006, 0.996937,
0.008, 0.995919,
0.01, 0.994902,
0.012, 0.993887,
0.014, 0.992873,
0.016, 0.991861,
0.018, 0.990851,
0.02, 0.989841,
0.022, 0.988834,
0.024, 0.987828,
0.026, 0.986823,
0.028, 0.98582,
0.03, 0.984818,
0.032, 0.983818,
0.034, 0.982819,
0.036, 0.981822,
0.038, 0.980826,
0.04, 0.979832,
0.042, 0.978839,
0.044, 0.977848,
0.046, 0.976858,
0.048, 0.97587,
0.05, 0.974883,
0.052, 0.973898,
0.054, 0.972914,
0.056, 0.971932,
0.058, 0.970951,
0.06, 0.969972,
0.062, 0.968994,
0.064, 0.968018,
0.066, 0.967043,
0.068, 0.96607,
0.07, 0.965099,
0.072, 0.964129,
0.074, 0.96316,
0.076, 0.962193,
0.078, 0.961228,
0.08, 0.960264,
0.082, 0.959301,
0.084, 0.958341,
0.086, 0.957381,
0.088, 0.956423,
0.09, 0.955467,
0.092, 0.954512,
0.094, 0.953559,
0.096, 0.952608,
0.098, 0.951657,
0.1, 0.950709,
0.102, 0.949762,
0.104, 0.948816,
0.106, 0.947872,
0.108, 0.94693,
0.11, 0.945989,
0.112, 0.94505,
0.114, 0.944112,
0.116, 0.943176,
0.118, 0.942242,
0.12, 0.941308,
0.122, 0.940377,
0.124, 0.939447,
0.126, 0.938519,
0.128, 0.937592,
0.13, 0.936667,
0.132, 0.935743,
0.134, 0.934821,
0.136, 0.9339,
0.138, 0.932982,
0.14, 0.932064,
0.142, 0.931148,
0.144, 0.930234,
0.146, 0.929322,
0.148, 0.92841,
0.15, 0.927501,
0.152, 0.926593,
0.154, 0.925687,
0.156, 0.924782,
0.158, 0.923879,
0.16, 0.922977,
0.162, 0.922077,
0.164, 0.921179,
0.166, 0.920282,
0.168, 0.919387,
0.17, 0.918493,
0.172, 0.917601,
0.174, 0.916711,
0.176, 0.915822,
0.178, 0.914935,
0.18, 0.914049,
0.182, 0.913165,
0.184, 0.912283,
0.186, 0.911402,
0.188, 0.910523,
0.19, 0.909646,
0.192, 0.90877,
0.194, 0.907895,
0.196, 0.907023,
0.198, 0.906151,
0.2, 0.905282,
0.202, 0.904414,
0.204, 0.903548,
0.206, 0.902683,
